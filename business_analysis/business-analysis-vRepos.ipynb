# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и подготовка к анализу</a></span><ul class="toc-item"><li><span><a href="#Загрузка-файлов-с-данными-и-изучение-общей-информации" data-toc-modified-id="Загрузка-файлов-с-данными-и-изучение-общей-информации-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка файлов с данными и изучение общей информации</a></span></li><li><span><a href="#Подготовка-данных-к-анализу" data-toc-modified-id="Подготовка-данных-к-анализу-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Подготовка данных к анализу</a></span></li><li><span><a href="#Вывод-по-подготовке-данных" data-toc-modified-id="Вывод-по-подготовке-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Вывод по подготовке данных</a></span></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей</a></span></li><li><span><a href="#Функция-для-расчёта-удержания" data-toc-modified-id="Функция-для-расчёта-удержания-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Функция для расчёта удержания</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li><li><span><a href="#Вывод-по-назначению-функций" data-toc-modified-id="Вывод-по-назначению-функций-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Вывод по назначению функций</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Создание-пользовательских-профилей" data-toc-modified-id="Создание-пользовательских-профилей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создание пользовательских профилей</a></span></li><li><span><a href="#Анализ-пользователей-по-странам" data-toc-modified-id="Анализ-пользователей-по-странам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ пользователей по странам</a></span></li><li><span><a href="#Анализ-пользователей-по-устройствам" data-toc-modified-id="Анализ-пользователей-по-устройствам-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Анализ пользователей по устройствам</a></span></li><li><span><a href="#Анализ-пользователей-по-рекламному-источнику" data-toc-modified-id="Анализ-пользователей-по-рекламному-источнику-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Анализ пользователей по рекламному источнику</a></span></li><li><span><a href="#Вывод-по-исследовательскому-анализу-данных" data-toc-modified-id="Вывод-по-исследовательскому-анализу-данных-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод по исследовательскому анализу данных</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-суммы-расходов-на-маркетинг-(CAC)" data-toc-modified-id="Анализ-общей-суммы-расходов-на-маркетинг-(CAC)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Анализ общей суммы расходов на маркетинг (CAC)</a></span></li><li><span><a href="#Анализ-средней-суммы-расходов-на-маркетинг-(CAC)" data-toc-modified-id="Анализ-средней-суммы-расходов-на-маркетинг-(CAC)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Анализ средней суммы расходов на маркетинг (CAC)</a></span></li><li><span><a href="#Вывод-по-маркетингу" data-toc-modified-id="Вывод-по-маркетингу-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Вывод по маркетингу</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы" data-toc-modified-id="Оценка-окупаемости-рекламы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Оценка окупаемости рекламы</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализ-графиков-конверсии-и-удержания-с-разбивкой-по-устройствам,-странам,-рекламным-каналам" data-toc-modified-id="Анализ-графиков-конверсии-и-удержания-с-разбивкой-по-устройствам,-странам,-рекламным-каналам-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Анализ графиков конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам</a></span><ul class="toc-item"><li><span><a href="#Графики-конверсии-и-удержания-с-разбивкой-по-устройствам" data-toc-modified-id="Графики-конверсии-и-удержания-с-разбивкой-по-устройствам-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Графики конверсии и удержания с разбивкой по устройствам</a></span></li><li><span><a href="#Графики-конверсии-и-удержания-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Графики-конверсии-и-удержания-с-разбивкой-по-рекламным-каналам-5.5.2"><span class="toc-item-num">5.5.2&nbsp;&nbsp;</span>Графики конверсии и удержания с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Графики-конверсии-и-удержания-с-разбивкой-по-странам" data-toc-modified-id="Графики-конверсии-и-удержания-с-разбивкой-по-странам-5.5.3"><span class="toc-item-num">5.5.3&nbsp;&nbsp;</span>Графики конверсии и удержания с разбивкой по странам</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.5.4"><span class="toc-item-num">5.5.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Выводы-по-оценке-окупаемости-рекламы" data-toc-modified-id="Выводы-по-оценке-окупаемости-рекламы-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Выводы по оценке окупаемости рекламы</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><span><a href="#Причины-неэффективности-привлечения-пользователей" data-toc-modified-id="Причины-неэффективности-привлечения-пользователей-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Причины неэффективности привлечения пользователей</a></span></li><li><span><a href="#Рекоммендации-для-отдела-маркетинга" data-toc-modified-id="Рекоммендации-для-отдела-маркетинга-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Рекоммендации для отдела маркетинга</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Анализ бизнес-показателей развлекательного приложения

# %% [markdown]
# Анализ бизнес-показателей развлекательного приложения Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Основная задача анализа — разобраться в причинах и помочь компании выйти в плюс.
#
# **Цель исследования**: выявить причины убытков компании и скорректировать работу рекламного отдела для получения прибыли.
#
# **Описание данных**
#
# В распоряжении данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - Лог сервера с данными об их посещениях, который хранится в таблице по адресу `/datasets/visits_info_short.csv`
# - Выгрузка их покупок за этот период, которая хранится в таблице по адресу `/datasets/orders_info_short.csv`
# - Рекламные расходы, которые хранятся в таблице по адресу `/datasets/costs_info_short.csv`
#
# В ходе проведения анализа необходимо изучить:
# - откуда приходят пользователи и какими устройствами они пользуются;
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент;
# - когда расходы на привлечение клиента окупаются;
# - какие факторы мешают привлечению клиентов.

# %% [markdown]
# ## Загрузка данных и подготовка к анализу

# %% [markdown]
# Перед началом работы с данными импортируем все необходимые библиотеки:

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %% [markdown]
# ### Загрузка файлов с данными и изучение общей информации

# %% [markdown]
# С помощью библиотеки Pandas откроем файлы и ознакомимся с данными:

# %%
visits, orders, costs = (
    pd.read_csv('/datasets/visits_info_short.csv'),
    pd.read_csv('/datasets/orders_info_short.csv'),
    pd.read_csv('/datasets/costs_info_short.csv')
)
display(visits.sample(10))
display(orders.sample(10))
display(costs.sample(10))
# Out:
#              User Id         Region   Device   Channel        Session Start  \
# 171020  229975828908  United States  Android    TipTop  2019-10-03 07:08:06
# 181743  685464367831  United States      Mac    TipTop  2019-10-10 17:46:42
# 101006  145740171068  United States      Mac  FaceBoom  2019-08-08 15:59:29
# 199454  159946339324  United States   iPhone  FaceBoom  2019-10-24 10:18:08
# 46950   586366676017  United States   iPhone  FaceBoom  2019-06-19 17:15:10
# 252658  626445025906        Germany  Android   organic  2019-07-30 19:11:09
# 56072   727638793545  United States  Android    TipTop  2019-06-27 23:25:12
# 128270    7955341070  United States   iPhone   organic  2019-08-30 01:58:48
# 200164  215878463754  United States   iPhone  FaceBoom  2019-10-24 15:03:49
# 290230  677557108981             UK       PC   LeapBob  2019-09-30 02:28:13
#
#                 Session End
# 171020  2019-10-03 08:00:12
# 181743  2019-10-10 18:17:21
# 101006  2019-08-08 16:55:28
# ...

# %% [markdown]
# Изучим **общую** информацию о данных:

# %%
display(visits.info())
display(orders.info())
display(costs.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# Рассмотрим **статистическую** информацию о данных:

# %%
display(visits.describe().T)
display(orders.describe().T)
display(costs.describe().T)
# Out:
#             count          mean           std       min           25%  \
# User Id  309901.0  4.997664e+11  2.887899e+11  599326.0  2.493691e+11
#
#                   50%           75%           max
# User Id  4.989906e+11  7.495211e+11  9.999996e+11
#            count          mean           std        min           25%  \
# User Id  40212.0  4.990295e+11  2.860937e+11  599326.00  2.511324e+11
# Revenue  40212.0  5.370608e+00  3.454208e+00       4.99  4.990000e+00
#
#                   50%           75%           max
# User Id  4.982840e+11  7.433327e+11  9.998954e+11
# Revenue  4.990000e+00  4.990000e+00  4.999000e+01
#         count       mean         std  min    25%     50%   75%    max
# costs  1800.0  58.609611  107.740223  0.8  6.495  12.285  33.6  630.0

# %% [markdown]
# Изучив общую информацию о данных можно сделать вывод о том, что для дальнейшей работы с данными необходимо:
# - привести названия столбцов к нижнему регистру;
# - привести названия столбцов, состоящие из нескольких слов, к "змеиному" регистру;
# - преобразовать тип данных столбцов _Session Start_, _Session End_, _Event Dt_ и _dt_

# %% [markdown]
# ### Подготовка данных к анализу

# %% [markdown]
# Выведем на экран названия стобцов каждой таблицы:

# %%
display(visits.columns)
display(orders.columns)
display(costs.columns)
# Out:
# Index(['User Id', 'Region', 'Device', 'Channel', 'Session Start',
#        'Session End'],
#       dtype='object')
# Index(['User Id', 'Event Dt', 'Revenue'], dtype='object')
# Index(['dt', 'Channel', 'costs'], dtype='object')

# %% [markdown]
# Необходимо привести все названия к **нижнему** регистру в соответствии с хорошим тоном:

# %%
visits.columns = visits.columns.str.lower()
orders.columns = orders.columns.str.lower()
costs.columns = costs.columns.str.lower()

# %% [markdown]
# Необходимо привести все названия к **змеиному** регистру в соответствии с хорошим тоном:

# %%
visits = visits.rename(
    columns={'user id':'user_id', 'session start':'session_start', 'session end':'session_end'}
)
orders = orders.rename(
    columns={'user id':'user_id', 'event dt':'event_dt'}
)

# %% [markdown]
# Проверим внесенные изменения, повторно вызвав названия стобцов:

# %%
display(visits.columns)
display(orders.columns)
display(costs.columns)
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')
# Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# Приведем **типы данных** столбцов к соответствующим их значениям:

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# Произведем поиск **явных дубликатов** таблиц и выведем их количество:

# %%
display(visits.duplicated().sum())
display(orders.duplicated().sum())
display(costs.duplicated().sum())
# Out:
# 0
# 0
# 0

# %% [markdown]
# Проверим таблицы на наличие **пропусков** и выведем их количество:

# %%
display(visits.isna().sum())
display(orders.isna().sum())
display(costs.isna().sum())
# Out:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64
# dt         0
# channel    0
# costs      0
# dtype: int64

# %% [markdown]
# **Явные дубликаты** отсутствуют. **Пропуски** в значениях также отсутстсвуют.

# %% [markdown]
# ### Вывод по подготовке данных

# %% [markdown]
# В ходе предварительной подготовки данных были произведены следующие действия:
# - загружены данные и изучена информация по ним;
# - названия столбцов были приведены к нижнему и "змеиному" регистру в соответствии с хорошим тоном
# - преобразованы типы данных столбцов
# - проведена проверка на наличие дубликатов

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# ### Функция для создания пользовательских профилей

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчёта удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта LTV и ROI

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для сглаживания фрейма

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Вывод по назначению функций

# %% [markdown]
# Для проведения дальнейшего анализа были назначены следующие функции:
# - `get_profiles` - функция для создания пользовательских профилей;
# - `get_retention` - функция для расчёта удержания;
# - `get_conversion` - функция для расчета конверсии;
# - `get_ltv` - функция для расчета LTV и ROI;
# - `filter_data` - функция для сглаживания датафрейма;
# - `plot_retention` - функция для визуализации удержания;
# - `plot_conversion` - функция для визуализации конверсии;
# - `plot_ltv_roi` - функция для визуализации LTV и ROI.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Создание пользовательских профилей

# %% [markdown]
# С помощью функции `get_profiles` создадим пользовательские профили и выведем их на экран:

# %%
profiles = get_profiles(visits, orders, costs)
display(profiles.head(10))
# Out:
#     user_id            first_ts       channel   device         region  \
# 0    599326 2019-05-07 20:58:57      FaceBoom      Mac  United States
# 1   4919697 2019-07-09 12:46:07      FaceBoom   iPhone  United States
# 2   6085896 2019-10-01 09:58:33       organic   iPhone         France
# 3  22593348 2019-08-22 21:35:48    AdNonSense       PC        Germany
# 4  31989216 2019-10-02 00:07:44       YRabbit   iPhone  United States
# 5  34186288 2019-05-09 17:29:23       organic  Android  United States
# 6  38448301 2019-08-16 11:56:00       organic  Android  United States
# 7  46006712 2019-06-30 03:46:29    AdNonSense  Android         France
# 8  58263264 2019-05-11 19:18:43      FaceBoom   iPhone  United States
# 9  59835779 2019-05-11 21:13:47  MediaTornado   iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# ...

# %% [markdown]
# Определим **минимальную** дату привлечения пользователей:

# %%
display(profiles.dt.min())
# Out:
# datetime.date(2019, 5, 1)

# %% [markdown]
# Определим **максимальную** дату привлечения пользователей:

# %%
display(profiles.dt.max())
# Out:
# datetime.date(2019, 10, 27)

# %% [markdown]
# ### Анализ пользователей по странам

# %% [markdown]
# Сгруппируем уникальных пользователей по стране и определим **количество** пользователей из каждой `страны`, а также **долю платящих** пользователей:

# %%
report_region = (profiles
          .groupby('region')
          .agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
)
report_region.columns = ['Пользователи', 'Платящие пользователи', 'Доля платящих']
report_region.head().sort_values(by='Пользователи', ascending=False)
# Out:
#                Пользователи  Платящие пользователи  Доля платящих
# region
# United States        100002                   6902       0.069019
# UK                    17575                    700       0.039829
# France                17450                    663       0.037994
# Germany               14981                    616       0.041119

# %% [markdown]
# Визуализируем полученные результаты:

# %%
profiles.pivot_table(
    index='dt',
    columns='region',
    values='user_id',
    aggfunc='nunique',
).plot(figsize=(15, 5), grid=True)

plt.title('Количество привлеченных пользователей')
plt.show()

# %% [markdown]
# **Выводы**:
# - большинство пользователей пришло в приложение из `United States` (100002 пользователя);
# - самая большая доля платящих пользователей также приходится на `United States` (6.9%)

# %% [markdown]
# ### Анализ пользователей по устройствам

# %% [markdown]
# Сгруппируем уникальных пользователей по устройству и определим **количество** пользователей для каждого `устройства`, а также **долю платящих** пользователей:

# %%
report_device = (profiles
          .groupby('device')
          .agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
)
report_device.columns = ['Пользователи', 'Платящие пользователи', 'Доля платящих']
report_device.head().sort_values(by='Пользователи', ascending=False)
# Out:
#          Пользователи  Платящие пользователи  Доля платящих
# device
# iPhone          54479                   3382       0.062079
# Android         35032                   2050       0.058518
# PC              30455                   1537       0.050468
# Mac             30042                   1912       0.063644

# %% [markdown]
# Визуализируем полученные результаты:

# %%
profiles.pivot_table(
    index='dt',
    columns='device',
    values='user_id',
    aggfunc='nunique',
).plot(figsize=(15, 5), grid=True)

plt.title('Количество привлеченных пользователей')
plt.show()

# %% [markdown]
# **Выводы**:
# - большинство пользуется приложением с `iPhone` (54479 пользователей);
# - самая большая доля платящих пользователей приходится на `Mac` (6.3%) и `iPhone` (6.2%)

# %% [markdown]
# ### Анализ пользователей по рекламному источнику

# %% [markdown]
# Сгруппируем уникальных пользователей по рекламным источникам и определим **количество** пользователей для каждого `рекламного источника`, а также **долю платящих** пользователей:

# %%
report_channel = (profiles
          .groupby('channel')
          .agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})
)
report_channel.columns = ['Пользователи', 'Платящие пользователи', 'Доля платящих']
report_channel.head(11).sort_values(by='Пользователи', ascending=False)
# Out:
#                     Пользователи  Платящие пользователи  Доля платящих
# channel
# organic                    56439                   1160       0.020553
# FaceBoom                   29144                   3557       0.122049
# TipTop                     19561                   1878       0.096007
# OppleCreativeMedia          8605                    233       0.027077
# LeapBob                     8553                    262       0.030633
# WahooNetBanner              8553                    453       0.052964
# RocketSuperAds              4448                    352       0.079137
# MediaTornado                4364                    156       0.035747
# YRabbit                     4312                    165       0.038265
# AdNonSense                  3880                    440       0.113402
# lambdaMediaAds              2149                    225       0.104700

# %% [markdown]
# Визуализируем полученные результаты:

# %%
profiles.pivot_table(
    index='dt',
    columns='channel',
    values='user_id',
    aggfunc='nunique',
).plot(figsize=(15, 5), grid=True)

plt.title('Количество привлеченных пользователей')
plt.show()

# %% [markdown]
# **Выводы**:
# - большинство пользователей приходят в приложение через рекламный источник `FaceBoom` (29144 пользователей);
# - самая большая доля платящих пользователей также приходит в приложение через рекламный источник `FaceBoom` (12.2%);
# - судя по графику самое большое количество пользователей приходят в приложение сами, без привлечения каких-либо рекламных источников, что является вполне ожидаемым результатом, однако, доля платящих пользователей из них самая низкая (всего 2%)

# %% [markdown]
# ### Вывод по исследовательскому анализу данных

# %% [markdown]
# По исследованию пользовательского портрета можно сделать следующие выводы о результате проводимой рекламной компании:
# - большинство пользователей пользуется приложением из `United States` (100002 пользователя), также на данный регион приходится самая большая доля платящих пользователей (6.9%);
# - большинство пользуется приложением с `iPhone` (54479 пользователей), доля платящих пользователей которого составляет 6.2%;
# - большинство пользователей приходят в приложение через рекламный источник `FaceBoom` (29144 пользователей), также на данный источник приходится самая большая доля платящих пользователей (12.2%)

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# Для дальнейшего анализа из расчетов следует исключить пользователей с органическим трафиком, поскольку компания за них ничего не платит:

# %%
profiles = profiles.query('channel != "organic"')

# %% [markdown]
# ### Анализ общей суммы расходов на маркетинг (CAC)

# %% [markdown]
# Рассчитаем общую сумму расходов на маркетинг:

# %%
print('Общая сумма расходов на маркетинг за исследуемый период:', round(profiles.acquisition_cost.sum()), '$')
# Out:
# Общая сумма расходов на маркетинг за исследуемый период: 105497 $

# %% [markdown]
# Проанализируем расходы на маркетинг по рекламным источникам:

# %%
cac_channel = (profiles
          .groupby('channel')
          .agg({'acquisition_cost': 'sum'})
)
cac_channel.columns = ['Рекламные затраты']
cac_channel.head(10).sort_values(by='Рекламные затраты', ascending=False)
# Out:
#                     Рекламные затраты
# channel
# TipTop                       54751.30
# FaceBoom                     32445.60
# WahooNetBanner                5151.00
# AdNonSense                    3911.25
# OppleCreativeMedia            2151.25
# RocketSuperAds                1833.00
# LeapBob                       1797.60
# lambdaMediaAds                1557.60
# MediaTornado                   954.48
# YRabbit                        944.22

# %% [markdown]
# Визуализируем изменение метрик во времени:

# %%
profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(10, 5))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# По полученным результатам можно сделать следующие выводы:
# - самым затратным рекламным источником является `TipTop` (54751.30 $);
# - за исследуемый период затраты на рекламный источник `TipTop` динамично **росли**

# %% [markdown]
# ### Анализ средней суммы расходов на маркетинг (CAC)

# %% [markdown]
# Рассчитаем среднюю сумму расходов на маркетинг на **одного** пользователя:

# %%
print('Средняя сумма расходов на маркетинг на одного пользователя за исследуемый период:', round(profiles.acquisition_cost.mean(), 2), '$')
# Out:
# Средняя сумма расходов на маркетинг на одного пользователя за исследуемый период: 1.13 $

# %% [markdown]
# Проанализируем среднюю сумму расходов на маркетинг на **одного** пользователя для каждого рекламного источника:

# %%
user_cac_channel = (profiles
          .groupby('channel')
          .agg({'acquisition_cost': 'mean'})
)
user_cac_channel.columns = ['Рекламные затраты']
user_cac_channel.head(11).sort_values(by='Рекламные затраты', ascending=False)
# Out:
#                     Рекламные затраты
# channel
# TipTop                       2.799003
# FaceBoom                     1.113286
# AdNonSense                   1.008054
# lambdaMediaAds               0.724802
# WahooNetBanner               0.602245
# RocketSuperAds               0.412095
# OppleCreativeMedia           0.250000
# YRabbit                      0.218975
# MediaTornado                 0.218717
# LeapBob                      0.210172

# %% [markdown]
# Визуализируем полученные результаты:

# %%
plt.figure(figsize=(20, 7))
plt.pie(x = user_cac_channel['Рекламные затраты'], 
        labels = user_cac_channel.index, 
        autopct="%.2f")
plt.title('Рекламные затраты на одного пользователя для каждого рекламного источника')
plt.show()

# %% [markdown]
# По полученным результатам можно сделать следующие выводы:
# - самым затратным рекламным источником на каждого пользователя является `TipTop` (2.8 $);
# - затраты на каждого пользователя рекламного источника `TipTop` превышают средние по всем данным в 2.5 раза;
# - доля рекламных затрат на источник `TipTop` составляет более 37%.

# %% [markdown]
# ### Вывод по маркетингу

# %% [markdown]
# По анализу маркетинга компании можно сделать следующие выводы:
# - самым затратным рекламным источником является `TipTop` (всего было потрачено 54751.30 $);
#
# - за исследуемый период затраты на рекламный источник `TipTop` динамично **росли** (наблюдается резкий рост затрат в середине мая, конце июня, конце июля и начале сентября);
# - самым затратным рекламным источником на каждого пользователя является `TipTop` (в среднем 2.8 $ на одного пользователя);
# - затраты на каждого пользователя рекламного источника `TipTop` превышают средние по всем данным в 2.5 раза;
# - доля рекламных затрат на источник `TipTop` составляет более 37% от общих.

# %% [markdown]
# ## Оценка окупаемости рекламы

# %% [markdown]
# Для дальнейшего анализа установим **момент** и **горизонт** анализа данных. Предположим, что на календаре 1 ноября 2019 года, а также зададим двахнедельный горизонт анализа:

# %%
observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# %% [markdown]
# ### Анализ общей окупаемости рекламы

# %% [markdown]
# Определим LTV и ROI:

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

# %% [markdown]
# Построим графики LTV и ROI:

# %%
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Посчитаем **удержание**:

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days
)

# %% [markdown]
# Построим графики удержания:

# %%
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# По полученным данным можно сделать следующие выводы:
# - Реклама не окупается. ROI в конце второй недели около 80%;
# - CAC на протяжении всего периода увеличивается, в особенности резкое увеличение происходит в конце мая 2019 года, возможно свою роль играет сезонность;
# - На LTV также влияет сезонность, но данный показатель стабильно растет, следовательно качество пользователей не ухудшается;
# - Динамика ROI отрицательная. Общая окупаемость рекламы падает вниз, в середине июня реклама окончательно перестала окупаться;
# - Платящие пользователи удерживаются дольше неплатящих;
# - Динамика удержания платящих пользователей стабальна, но достаточно низкая.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %% [markdown]
# Посчитаем LTV и ROI с разбивкой по **устройствам** и построим графики:

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['device']
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Посчитаем удержание и построим графики с разбивкой по **устройствам**:

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['device']
)
plot_retention(retention_grouped, retention_history, horizon_days, window=14)

# %% [markdown]
# По полученным данным можно сделать следующие выводы:
# - Реклама для пользователей `iPhone`не окупается. ROI в конце второй недели около 70%, в то время как реклама пользователей `PC` наичнает приносить прибыль в коцне второй недели;
# - CAC для пользователей `iPhone` и `Мac` самая высокая, в то время, как для пользователей `PC` самая низкая;
# - На LTV влияет сезонность, но данный показатель стабильно растет, следовательно качество пользователей не ухудшается;
# - Динамика ROI `iPhone` отрицательная. Общая окупаемость рекламы падает вниз, в конце июня реклама окончательно перестала окупаться. В свою очередь реклама для пользователей `PC` окупается на протяжении всего двухнедельного периода;
# - Платящие пользователи `PC` удерживаются дольше пользователей `iPhone`;
# - Динамика удержания платящих пользователей `PC` в большинстве времени выше пользователей `iPhone`.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %% [markdown]
# Посчитаем LTV и ROI с разбивкой по **рекламным каналам** и построим графики:

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['channel']
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Посчитаем удержание и построим графики с разбивкой по **рекламным каналам**:

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['channel']
)
plot_retention(retention_grouped, retention_history, horizon_days, window=14)

# %% [markdown]
# По полученным данным можно сделать следующие выводы:
# - Реклама от каналов `FaceBoom` и `TipTop` не окупается. ROI в конце второй недели около 80-85%, в то время как реклама от канала `YRabbit` и некоторых других каналов наичнает приносить прибыль уже в начале первой недели;
# - CAC для канала `TipTop` самая высокая, в то время, как для пользователей `YRabbit` одна из самых низких;
# - На LTV влияет сезонность, но данный показатель у каналов `TipTop` и `lambdaMediaAds` заметно выше, чем у других каналов;
# - Динамика ROI `FaceBoom` и `TipTop` стабильная, но ниже уровня окупаемости. В свою очередь у канала `YRabbit` динамика стабильно выше уровня окупаемости;
# - Платящие пользователи, пришедшие с канала `FaceBoom` практически не задерживаются в приложении.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %% [markdown]
# Посчитаем LTV и ROI с разбивкой по **странам** и построим графики:

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=['region']
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# Посчитаем удержание и построим графики с разбивкой по **странам**:

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=['region']
)
plot_retention(retention_grouped, retention_history, horizon_days, window=14)

# %% [markdown]
# По полученным данным можно сделать следующие выводы:
# - Реклама в `United States` не окупается. ROI в конце второй недели около 70%, в то время как реклама в остальных странах наичнает приносить прибыль уже в середине первой недели;
# - CAC в `United States` самая высокая и динамично растет, в то время, как в остальных странах она стабильно низкая;
# - На LTV влияет сезонность, но данный показатель в `United States` заметно выше, чем в других странах;
# - Динамика ROI `United States` отрицательная, падает ниже уровня окупаемости в конце июня. В свою очередь в остальных странах динамика стабильно выше уровня окупаемости;
# - Платящие пользователи `United States` гораздо меньше задерживаются в приложении.

# %% [markdown]
# ### Анализ графиков конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам

# %% [markdown]
# #### Графики конверсии и удержания с разбивкой по устройствам

# %% [markdown]
# Считаем конверсию и строим графики с разбивкой по **устройствам**:

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['device']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# #### Графики конверсии и удержания с разбивкой по рекламным каналам

# %% [markdown]
# Считаем конверсию и строим графики с разбивкой по **рекламным каналам**:

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['channel']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# #### Графики конверсии и удержания с разбивкой по странам

# %% [markdown]
# Считаем конверсию и строим графики с разбивкой по **странам**:

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=['region']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# #### Выводы

# %% [markdown]
# По полученным результатам можно сделать выводы:
# - Конверсия пользователей из `United States`, пользующихся `iPhone` и `Mac`, привлеченных рекламным источником `FaceBoom` самая высокая;
# - Удержание платящих пользователей из `United States` самое низкое;
# - Удержание платящих пользователей `iPhone` и `Mac` ниже `PC`;
# - Удержание платящих пользователей из `FaceBoom` самое низкое и стремится к нулевому.

# %% [markdown]
# ### Выводы по оценке окупаемости рекламы

# %% [markdown]
# В ходе проведенного анализа были получены следующие результаты:
# - В целом, реклама, направленная на привлечение пользователей, **не окупается**;
# - Негативное влияние на окупаемость рекламы оказывает страна `United States`, устройства `iPhone` и `Mac`, а также рекламные каналы `FaceBoom` (за счет низкого удержания пользователей) и `TipTop` (за счет высоких рекламных затрат).

# %% [markdown]
# Рекламному отделу рекоммендуется:
# - Обратиться к разработчикам приложения Procrastinate Pro+ по поводу возможных проблем с работой приложения;
# - Скорректировать или прервать дальнейшее сотрудничество с рекламными источниками `FaceBoom`  и `TipTop`.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# ### Причины неэффективности привлечения пользователей

# %% [markdown]
# Можно выделить следующие причины:
# - Пользователи из страны-лидера по количеству привлечений `United States` быстро покидают приложение, совершая мало покупок;
# - Низкий уровень удержания пользователей с устройств `Mac` и `iPhone`, а ведь именно с этих устройств происходит наибольший поток платящих пользователей;
# - Нерациональная трата рекламных денежных средств, а именно большие расходы на источник `TipTop`, являющийся самым дорогим, но далеко не самым эффективным по удержанию, а также расходы на относительно дорогой источник `FaceBoom`, который приводит множество новых пользователей, которые совершают недорогие покупки.

# %% [markdown]
# ### Рекоммендации для отдела маркетинга

# %% [markdown]
# Рекламному отделу необходимо:
# - Обратиться к разработчикам приложения Procrastinate Pro+. Возможно, в регионе `United States` приложение работает некорректно, либо поддержка данного региона и вовсе отсутствует, в виду чего пользователи неохотно остаются в приложении;
# - Увеличить рекламный бюджет в странах `France`, `Germany`, `UK`, пользователи которых стабильно совершают крупные покупки;
# - Обратиться к разработчикам приложения Procrastinate Pro+. Возможно, в работе приложения на устройствах `iPhone` и `Mac` приложение работает некорректно, имеются технические проблемы;
# - Увеличить привлечение пользователей с `PC`;
# - Скорректировать или прервать дальнейшее сотрудничество с рекламными источниками `FaceBoom` (возможно, предоставляет ложные данные о приложении в своей рекламе) и `TipTop` (стоимость данного истоячника достаточно велика и несет за собой убытки компании);
# - Увеличить рекламные расходы на такой прибыльный источник, как `YRabbit`
