# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных-и-подготовка-к-анализу" data-toc-modified-id="Загрузка-данных-и-подготовка-к-анализу-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных и подготовка к анализу</a></span><ul class="toc-item"><li><span><a href="#Загрузка-файла-с-данными-и-изучение-общей-информации" data-toc-modified-id="Загрузка-файла-с-данными-и-изучение-общей-информации-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка файла с данными и изучение общей информации</a></span></li><li><span><a href="#Подготовка-данных-к-анализу" data-toc-modified-id="Подготовка-данных-к-анализу-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Подготовка данных к анализу</a></span></li><li><span><a href="#Вывод-по-подготовке-данных" data-toc-modified-id="Вывод-по-подготовке-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Вывод по подготовке данных</a></span></li></ul></li><li><span><a href="#Проведение-исследовательского-анализа-данных-(EDA)" data-toc-modified-id="Проведение-исследовательского-анализа-данных-(EDA)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Проведение исследовательского анализа данных (EDA)</a></span><ul class="toc-item"><li><span><a href="#Изучение-статистической-информации-о-данных" data-toc-modified-id="Изучение-статистической-информации-о-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изучение статистической информации о данных</a></span></li><li><span><a href="#Средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался" data-toc-modified-id="Средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался</a></span></li><li><span><a href="#Столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток)" data-toc-modified-id="Столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)</a></span></li><li><span><a href="#Матрица-корреляций" data-toc-modified-id="Матрица-корреляций-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Матрица корреляций</a></span></li></ul></li><li><span><a href="#Построение-модели-прогнозирования-оттока-клиентов" data-toc-modified-id="Построение-модели-прогнозирования-оттока-клиентов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Построение модели прогнозирования оттока клиентов</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Выводы-по-построению-и-изучению-моделей:" data-toc-modified-id="Выводы-по-построению-и-изучению-моделей:-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Выводы по построению и изучению моделей:</a></span></li></ul></li><li><span><a href="#Кластеризация-клиентов" data-toc-modified-id="Кластеризация-клиентов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Кластеризация клиентов</a></span><ul class="toc-item"><li><span><a href="#Стандартизация-данных" data-toc-modified-id="Стандартизация-данных-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Стандартизация данных</a></span></li><li><span><a href="#Матрица-расстояний-и-дендограмма" data-toc-modified-id="Матрица-расстояний-и-дендограмма-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Матрица расстояний и дендограмма</a></span></li><li><span><a href="#Обучение-модели-кластеризации-и-прогноз-кластеров-клиентов" data-toc-modified-id="Обучение-модели-кластеризации-и-прогноз-кластеров-клиентов-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Обучение модели кластеризации и прогноз кластеров клиентов</a></span></li><li><span><a href="#Средние-значения-признаков-для-кластеров" data-toc-modified-id="Средние-значения-признаков-для-кластеров-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Средние значения признаков для кластеров</a></span></li><li><span><a href="#Распределения-признаков-для-кластеров" data-toc-modified-id="Распределения-признаков-для-кластеров-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Распределения признаков для кластеров</a></span></li><li><span><a href="#Доля-оттока-каждого-кластера" data-toc-modified-id="Доля-оттока-каждого-кластера-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Доля оттока каждого кластера</a></span></li></ul></li><li><span><a href="#Выводы-и-базовые-рекомендации-по-работе-с-клиентами" data-toc-modified-id="Выводы-и-базовые-рекомендации-по-работе-с-клиентами-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы и базовые рекомендации по работе с клиентами</a></span><ul class="toc-item"><li><span><a href="#Проделанная-работа" data-toc-modified-id="Проделанная-работа-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Проделанная работа</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Выводы</a></span></li><li><span><a href="#Рекомендации-для-стратегии-взаимодействия-с-клиентами-и-их-удержания" data-toc-modified-id="Рекомендации-для-стратегии-взаимодействия-с-клиентами-и-их-удержания-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Рекомендации для стратегии взаимодействия с клиентами и их удержания</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Подготовка стратегии по борьбе с оттоком клиентов из сети фитнес-клубов

# %% [markdown]
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с клиентами на основе аналитических данных.
# Распространённая проблема фитнес-клубов и других сервисов — отток клиентов.
# Для фитнес-центра можно считать, что клиент попал в отток, если за последний месяц ни разу не посетил спортзал. Конечно, не исключено, что он уехал на Бали и по приезде обязательно продолжит ходить на фитнес. Однако чаще бывает наоборот. Если клиент начал новую жизнь с понедельника, немного походил в спортзал, а потом пропал — скорее всего, он не вернётся.
# Чтобы бороться с оттоком, отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество клиентских анкет.
#
# **Цель исследования**: провести анализ и подготовить план действий по удержанию клиентов.
#
# **Описание данных**
#
# Таблица, которая содержит данные на месяц до оттока и факт оттока на определённый месяц, хранится по адресу `/datasets/gym_churn.csv`:
#
# 1. Данные клиента за предыдущий до проверки факта оттока месяц:
# - `'gender'` — пол;
# - `'Near_Location'` — проживание или работа в районе, где находится фитнес-центр;
# - `'Partner'` — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
# - `'Promo_friends'` — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
# - `'Phone'` — наличие контактного телефона;
# - `'Age'` — возраст;
# - `'Lifetime'` — время с момента первого обращения в фитнес-центр (в месяцах).
# 2. Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
# - `'Contract_period'` — длительность текущего действующего абонемента (месяц, 6 месяцев, год);
# - `'Month_to_end_contract'` — срок до окончания текущего действующего абонемента (в месяцах);
# - `'Group_visits'` — факт посещения групповых занятий;
# - `'Avg_class_frequency_total'` — средняя частота посещений в неделю за все время с начала действия абонемента;
# - `'Avg_class_frequency_current_month'` — средняя частота посещений в неделю за предыдущий месяц;
# - `'Avg_additional_charges_total'` — суммарная выручка от других услуг фитнес-центра: кафе, спорттовары, косметический и массажный салон.
# 3. `'Churn'` — факт оттока в текущем месяце.

# %% [markdown]
# ## Загрузка данных и подготовка к анализу

# %% [markdown]
# Перед началом работы с данными импортируем все необходимые библиотеки:

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans

pd.set_option('display.max_columns', None)
pd.options.display.float_format = '{:,.2f}'.format
sns.set(rc={'figure.figsize':(16,9)})

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %% [markdown]
# ### Загрузка файла с данными и изучение общей информации

# %%
try:
    df = pd.read_csv('D:\\Яндекс\\Проект 9 - Отток клиентов фитнес-клуба\\gym_churn.csv')
except:
    df = pd.read_csv('/datasets/gym_churn.csv')
df.sample(10)
# Out:
#       gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 1123       1              1        1              1      1               12
# 52         1              1        0              1      1                1
# 1109       0              1        0              0      1               12
# 3633       1              1        1              0      1                1
# 3119       1              0        1              0      1                6
# 3761       0              1        0              0      1                1
# 3413       1              1        1              0      1                1
# 683        0              1        1              1      1                1
# 2811       0              1        1              0      1                1
# 727        0              0        1              0      1                1
#
#       Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# ...

# %% [markdown]
# Выведем на экран **размер** датасета:

# %%
df.shape
# Out:
# (4000, 14)

# %% [markdown]
# Изучим **общую** информацию о данных:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# Изучив общую информацию о данных можно сделать вывод о том, что для дальнейшей работы с данными необходимо:
# - привести названия столбцов к **нижнему** регистру.

# %% [markdown]
# ### Подготовка данных к анализу

# %% [markdown]
# Рассмотрим **названия столбцов**:

# %%
df.columns.tolist()
# Out:
# ['gender',
#  'Near_Location',
#  'Partner',
#  'Promo_friends',
#  'Phone',
#  'Contract_period',
#  'Group_visits',
#  'Age',
#  'Avg_additional_charges_total',
#  'Month_to_end_contract',
#  'Lifetime',
#  'Avg_class_frequency_total',
#  'Avg_class_frequency_current_month',
#  'Churn']

# %% [markdown]
# Приведем названия столбцов к **нижнему** регистру:

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# Убедимся, что изменения действительно внесены:

# %%
df.columns.tolist()
# Out:
# ['gender',
#  'near_location',
#  'partner',
#  'promo_friends',
#  'phone',
#  'contract_period',
#  'group_visits',
#  'age',
#  'avg_additional_charges_total',
#  'month_to_end_contract',
#  'lifetime',
#  'avg_class_frequency_total',
#  'avg_class_frequency_current_month',
#  'churn']

# %% [markdown]
# Произведем поиск **явных дубликатов** таблиц и выведем их количество:

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Явные дубликаты** отсутствуют.

# %% [markdown]
# Проверим данные на наличие **пропусков** и выведем их количество:

# %%
df.isna().sum()
# Out:
# gender                               0
# near_location                        0
# partner                              0
# promo_friends                        0
# phone                                0
# contract_period                      0
# group_visits                         0
# age                                  0
# avg_additional_charges_total         0
# month_to_end_contract                0
# lifetime                             0
# avg_class_frequency_total            0
# avg_class_frequency_current_month    0
# churn                                0
# dtype: int64

# %% [markdown]
# **Пропуски** в значениях отсутстсвуют.

# %% [markdown]
# ### Вывод по подготовке данных

# %% [markdown]
# В ходе предварительной подготовки данных к анализу были произведены следующие действия:
# - загружены данные и изучена информация по ним;
# - названия столбцов были приведены к нижнему регистру в соответствии с хорошим тоном;
# - проведена проверка на наличие явных дубликатов и пропусков.

# %% [markdown]
# ## Проведение исследовательского анализа данных (EDA)

# %% [markdown]
# ### Изучение статистической информации о данных

# %% [markdown]
# Рассмотрим **статистическую** информацию о данных методом _describe()_:

# %%
df.describe().T
# Out:
#                                      count   mean   std   min   25%    50%  \
# gender                            4,000.00   0.51  0.50  0.00  0.00   1.00
# near_location                     4,000.00   0.85  0.36  0.00  1.00   1.00
# partner                           4,000.00   0.49  0.50  0.00  0.00   0.00
# promo_friends                     4,000.00   0.31  0.46  0.00  0.00   0.00
# phone                             4,000.00   0.90  0.30  0.00  1.00   1.00
# contract_period                   4,000.00   4.68  4.55  1.00  1.00   1.00
# group_visits                      4,000.00   0.41  0.49  0.00  0.00   0.00
# age                               4,000.00  29.18  3.26 18.00 27.00  29.00
# avg_additional_charges_total      4,000.00 146.94 96.36  0.15 68.87 136.22
# month_to_end_contract             4,000.00   4.32  4.19  1.00  1.00   1.00
# lifetime                          4,000.00   3.72  3.75  0.00  1.00   3.00
# ...

# %% [markdown]
# Изучив средние значения и стандартные отклонения можно сделать следующие **выводы**:
# - Распределение по полу примерно одинаково;
# - Большинство клиентов (85%) живет или работает рядом с фитнес-клубом;
# - Около половины клиентов (49%) являются сотрудниками партнерских организаций;
# - Часть клиентов (31%) были записаны в рамках акции "Приведи друга";
# - 90% клиентов оставили номера мобильных телефонов;
# - 50% клиентов покупает месячные абонементы, а 25% покупают абонементы на 6 месяцев;
# - 41% клиентов посещают групповые занятия;
# - Средний возраст клиентов 29 лет;
# - В среднем клиенты тратят 147 у.е. на другие услуги фитнес-центра (кафе, спорттовары, косметический и массажный салон);
# - У 50% клиентов абонемент заканчивается через 1 месяц, а у 25% через 6 месяцев;
# - В среднем клиенты посещают фитнес-клуб 3.7 месяцев;
# - Средняя частота посещений фитнес-клуба в неделю - 1.88 раз, однако, за последний месяц произошло снижение на 6% (до 1.77 раз);
# - Доля оттока клиентов - 27%.

# %% [markdown]
# ### Средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался

# %% [markdown]
# Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался. Для этого сгруппируем данные методом _groupby()_:

# %%
df_avg_churn = df.groupby('churn').mean()
df_avg_churn.T
# Out:
# churn                                  0      1
# gender                              0.51   0.51
# near_location                       0.87   0.77
# partner                             0.53   0.36
# promo_friends                       0.35   0.18
# phone                               0.90   0.90
# contract_period                     5.75   1.73
# group_visits                        0.46   0.27
# age                                29.98  26.99
# avg_additional_charges_total      158.45 115.08
# month_to_end_contract               5.28   1.66
# lifetime                            4.71   0.99
# avg_class_frequency_total           2.02   1.47
# avg_class_frequency_current_month   2.03   1.04

# %% [markdown]
# По полученной таблице можно сделать следующие **выводы**:
# - Отток клиентов не зависит от пола, мужчины и женщины попадают в категорию оттока примерно одинаково;
# - Клиенты, проживающие рядом с фитнес-клубом реже попадают в отток, что вполне предсказуемо;
# - Сотрудники компаний-партнеров реже перестают посещать фитнесс-клуб чем остальные клиенты;
# - Клиенты, пришедшие по акции "Приведи друга" уходят в отток почти в 2 раза реже;
# - Отток не зависит от наличия номера мобильного телефона клиента;
# - Отток клиентов, как правило, происходит среди тех, кто приобретает абонемент занятий на 1 месяц;
# - Клиенты, посещающие групповые занятия, реже  попадают в отток;
# - Клиенты, тратящие большую сумму на иные услуги фитнес-клуба попадают в отток реже;
# - Перед попаданием в отток клиенты реже посещают занятия (в среднем 1 раз в неделю);
# - В основном остаются те клиенты кто посещает занятия 2 раза в неделю.

# %% [markdown]
# ### Столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)

# %% [markdown]
# Построим графики распределения значений для всех признаков:

# %%
for column in ['gender', 'near_location', 'partner', 'promo_friends', 'phone', 'contract_period', 'group_visits']:
    plt.figure(figsize=(10, 5))
    sns.countplot(x = df[column], hue='churn', data=df)
    plt.legend(labels=['Оставшиеся', 'Отток'], fontsize = 12)
    plt.title(column)
    plt.show()

# %%
left = df[df['churn'] == 0]
stayed = df[df['churn'] == 1]
for column in ['age', 'avg_additional_charges_total', 'avg_class_frequency_total', 
               'lifetime', 'avg_class_frequency_current_month', 'month_to_end_contract']: 
  plt.figure(figsize=(10, 5))
  plt.title(column)
  sns.distplot(left[column])
  sns.distplot(stayed[column])
  plt.legend(['Оставшиеся', 'Отток'])
  plt.show()

# %% [markdown]
# Полученные графики полностью подтверждают ранее сделанные выводы.

# %% [markdown]
# ### Матрица корреляций

# %% [markdown]
# Построим матрицу корреляций и отобразим её:

# %%
sns.set(font_scale=1.1)
corr_m = df.corr().round(2)
plt.figure(figsize = (18, 10))
sns.heatmap(corr_m,  annot = True, fmt = '.2g', linewidths = .5, cmap = "PuOr", linecolor = 'black')
plt.title('Матрица корреляций', fontsize = 20)
plt.xlabel('Признаки', fontsize = 15) 
plt.ylabel('Признаки', fontsize = 15)
plt.show()

# %% [markdown]
# Имеются **мультиколлинеарные признаки**:
# - `contract_period` и `month_to_end_contact`;
# - `avg_class_frequency_current_month` и `avg_class_frequency_total`.
#
# Также есть признаки, у которых **коэффициент корреляции близок к нулю**:
# - `gender`;
# - `phone`.

# %% [markdown]
# ## Построение модели прогнозирования оттока клиентов

# %% [markdown]
# Построим модель бинарной классификации пользователей, где целевой признак - факт оттока пользователя в следующем месяце:
# - Разобъем данные на обучающую и валидационную выборки функцией train_test_split();
# - Обучим модель на train-выборке логистической регрессией и случайным лесом;
# - Оценим метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравним по ним модели и на основании метрик выберем лучшую.

# %% [markdown]
# Разделим данные на признаки (матрица X) и целевую переменную (y):

# %%
X = df.drop(['churn'], axis = 1)
y = df['churn']

# %% [markdown]
# Разделим модель на обучающую и валидационную выборку:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# Преобразуем обучающий и валидационный наборы данных

# %%
scaler = StandardScaler()
X_train_st = scaler.fit_transform(X_train)
X_test_st = scaler.transform(X_test)

# %% [markdown]
# ### Логистическая регрессия

# %% [markdown]
# Получим метрики _accuracy_, _precision_ и _recall_ для модели **логистической регрессии** на валидационной выборке:

# %%
lr_model = LogisticRegression(random_state=0)
lr_model.fit(X_train_st, y_train)
lr_predictions = lr_model.predict(X_test_st)
lr_probabilities = lr_model.predict_proba(X_test_st)[:,1]

# %% [markdown]
# Напишем **функцию** для вывода необходимых метрик обучающих моделей:

# %%
def print_all_metrics(y_true, y_pred, y_proba, title):
    print(title)
    print('Accuracy: {:.2f}'.format(accuracy_score(y_true, y_pred)))
    print('Precision: {:.2f}'.format(precision_score(y_true, y_pred)))
    print('Recall: {:.2f}'.format(recall_score(y_true, y_pred)))

# %% [markdown]
# Выведем на экран необходимые метрики для модели **логистической регресии**:

# %%
print_all_metrics(y_test, lr_predictions, lr_probabilities, title = 'Метрики для модели логистической регрессии:')
# Out:
# Метрики для модели логистической регрессии:
# Accuracy: 0.92
# Precision: 0.85
# Recall: 0.83

# %% [markdown]
# ### Случайный лес

# %% [markdown]
# Получим метрики _accuracy_, _precision_ и _recall_ для модели **случайного леса** на валидационной выборке:

# %%
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0) 
rf_model.fit(X_train_st, y_train)
rf_predictions = rf_model.predict(X_test_st)
rf_probabilities = rf_model.predict_proba(X_test_st)[:,1]

# %% [markdown]
# Выведем на экран необходимые метрики для модели **случайного леса**:

# %%
print_all_metrics(y_test, rf_predictions, rf_probabilities, title = 'Метрики для модели случайного леса:')
# Out:
# Метрики для модели случайного леса:
# Accuracy: 0.92
# Precision: 0.84
# Recall: 0.81

# %% [markdown]
# ### Выводы по построению и изучению моделей:

# %% [markdown]
# После построения двух моделей можно сделать следующие **выводы**:
# - Доля правильных ответов у обеих моделей примерно одинакова (0.92);
# - Точность прогнозов и полнота выше у модели **логистической регресии**;
# - Таким образом, модель логистической регрессии показала себя лучше.

# %% [markdown]
# ## Кластеризация клиентов

# %% [markdown]
# ### Стандартизация данных

# %% [markdown]
# Стандартизируем данные:

# %%
scaler = StandardScaler()
df_drop_sc = scaler.fit_transform(df.drop(columns = ['churn']))

# %% [markdown]
# ### Матрица расстояний и дендограмма

# %% [markdown]
# Построим матрицу расстояний на стандартизованной матрице признаков и нарисуем дендрограмму:

# %%
linked = linkage(df_drop_sc, method = 'ward')
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.title('Дендрограмма иерархической кластеризации клиентов фитнес-клуба')
plt.show()

# %% [markdown]
# По полученной дендограмме видно, что модель делит клиентов фитнес-клуба на 4 кластера, однако, 4 кластер слишком большой. Поэтому при обучении модели примем число кластеров `n=5`.

# %% [markdown]
# ### Обучение модели кластеризации и прогноз кластеров клиентов

# %% [markdown]
# Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры клиентов:

# %%
km = KMeans(n_clusters = 5)
labels = km.fit_predict(df_drop_sc)
df['cluster_km'] = labels
df.sample(10)
# Out:
#       gender  near_location  partner  promo_friends  phone  contract_period  \
# 1252       0              1        1              1      1               12
# 3917       1              1        1              0      0               12
# 1544       1              1        1              0      0               12
# 193        0              0        1              0      0                6
# 104        0              1        0              0      1               12
# 2859       0              1        0              0      1                1
# 2790       1              1        1              1      0                6
# 874        0              1        0              0      1               12
# 1104       1              1        1              1      1                6
# 733        1              1        1              0      1                6
#
#       group_visits  age  avg_additional_charges_total  month_to_end_contract  \
# ...

# %% [markdown]
# ### Средние значения признаков для кластеров

# %% [markdown]
# Посмотрим на средние значения признаков для кластеров:

# %%
df.groupby('cluster_km').mean().T
# Out:
# cluster_km                             0      1      2      3      4
# gender                              0.52   0.48   0.50   0.56   0.50
# near_location                       0.86   1.00   0.96   0.98   0.00
# partner                             0.47   0.35   0.78   0.36   0.46
# promo_friends                       0.31   0.24   0.57   0.24   0.08
# phone                               0.00   1.00   1.00   1.00   1.00
# contract_period                     4.79   1.95  10.92   2.69   2.35
# group_visits                        0.43   0.34   0.55   0.47   0.22
# age                                29.30  28.17  29.99  30.11  28.48
# avg_additional_charges_total      143.96 131.52 160.88 161.59 135.46
# month_to_end_contract               4.48   1.86   9.98   2.48   2.20
# lifetime                            3.92   2.43   4.75   4.89   2.81
# avg_class_frequency_total           1.85   1.25   1.98   2.85   1.66
# avg_class_frequency_current_month   1.72   1.01   1.97   2.85   1.48
# ...

# %% [markdown]
# По средним значениям можно заметить, что из всех кластеров лидирует `номер 2`:
# - Самый низкий отток клиентов (3%);
# - Средняя длительность действующего абонемента около 11 месяцев;
# - Почти самые высокие траты на иные услуги фитнес-клуба;
# - Посещают фитнес-клуб достаточно продолжительное время (около 5 месяцев);
# - В среднем около 10 месяцев до окончания действия абонемента.

# %% [markdown]
# ### Распределения признаков для кластеров

# %% [markdown]
# Построим распределения признаков для кластеров:

# %%
for column in ['gender', 'near_location', 'partner', 'promo_friends', 'phone', 'contract_period', 'group_visits']:
    plt.figure(figsize=(10, 5))
    sns.countplot(x = df[column], hue='cluster_km', data=df)
    plt.legend(labels=['0', '1', '2', '3', '4'], fontsize = 12)
    plt.title(column)
    plt.show()

# %%
for column in ['age', 'avg_additional_charges_total', 'avg_class_frequency_total', 
               'lifetime', 'avg_class_frequency_current_month', 'month_to_end_contract']:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x = 'cluster_km', y = df[column], data = df)
    plt.show()

# %% [markdown]
# Полученные графики подтверждают уверенное лидерство кластера `номер 2`.

# %% [markdown]
# ### Доля оттока каждого кластера

# %% [markdown]
# Для каждого полученного кластера посчитаем долю оттока методом _groupby()_:

# %%
df_persent = df.groupby('cluster_km')['churn'].mean().reset_index()
df_persent.columns = [['Кластер', 'Доля оттока']]
df_persent
# Out:
#   Кластер Доля оттока
# 0       0        0.27
# 1       1        0.52
# 2       2        0.03
# 3       3        0.07
# 4       4        0.44

# %% [markdown]
# Самые **надежные** кластеры:
# - `номер 2`;
# - `номер 0`.
#
# Склонны к **оттоку**:
# - `номер 1`;
# - `номер 3`.

# %% [markdown]
# ## Выводы и базовые рекомендации по работе с клиентами

# %% [markdown]
# ### Проделанная работа

# %% [markdown]
# В ходе проведения анализа была проделана следующая работа:
#
# **1. Подготовка данных к анализу, в ходе которой:**
# - Загружены данные и изучена информация по ним;
# - Названия столбцов были приведены к нижнему регистру в соответствии с хорошим тоном;
# - Проведена проверка на наличие явных дубликатов и пропусков.
#
# **2. Проведен исследовательский анализ данных (EDA):**
# - Изучена статистическая информация о данных;
# - Изучены средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался;
# - Построены столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);
# - Построена и проанализирована матрица корреляций.
#
# **3. Построены и изучены модели прогнозирования оттока клиентов**:
# - Построена модель логистической регрессии;
# - Построена модель случайного леса;
# - Проведено сравнение полученных метрик.
#
# **4. Произведена кластеризация клиентов**:
# - Произведена стандартизация данных;
# - Построена матрица расстояний и нарисована дендограмма;
# - Обучена модель кластеризации и произведен прогноз кластеров клиентов;
# - Изучены средние значения признаков для кластеров;
# - Построены распределения признаков для кластеров;
# - Изучена доля оттока клиентов каждого кластера

# %% [markdown]
# ### Выводы

# %% [markdown]
# В ходе проведения анализа были получены следующие выводы:
# - Распределение по полу примерно одинаково;
# - Большинство клиентов (85%) живет или работает рядом с фитнес-клубом;
# - Около половины клиентов (49%) являются сотрудниками партнерских организаций;
# - Часть клиентов (31%) были записаны в рамках акции "Приведи друга";
# - 90% клиентов оставили номера мобильных телефонов;
# - 50% клиентов покупает месячные абонементы, а 25% покупают абонементы на 6 месяцев;
# - 41% клиентов посещают групповые занятия;
# - Средний возраст клиентов 29 лет;
# - В среднем клиенты тратят 147 у.е. на другие услуги фитнес-центра (кафе, спорттовары, косметический и массажный салон);
# - У 50% клиентов абонемент заканчивается через 1 месяц, а у 25% через 6 месяцев;
# - В среднем клиенты посещают фитнес-клуб 3.7 месяцев;
# - Средняя частота посещений фитнес-клуба в неделю - 1.88 раз, однако, за последний месяц произошло снижение на 6% (до 1.77 раз);
# - Доля оттока клиентов - 27%;
# - Отток клиентов не зависит от пола, мужчины и женщины попадают в категорию оттока примерно одинаково;
# - Клиенты, проживающие рядом с фитнес-клубом реже попадают в отток, что вполне предсказуемо;
# - Сотрудники компаний-партнеров реже перестают посещать фитнесс-клуб чем остальные клиенты;
# - Клиенты, пришедшие по акции "Приведи друга" уходят в отток почти в 2 раза реже;
# - Отток не зависит от наличия номера мобильного телефона клиента;
# - Отток клиентов, как правило, происходит среди тех, кто приобретает абонемент занятий на 1 месяц;
# - Клиенты, посещающие групповые занятия, реже  попадают в отток;
# - Клиенты, тратящие большую сумму на иные услуги фитнес-клуба попадают в отток реже;
# - Перед попаданием в отток клиенты реже посещают занятия (в среднем 1 раз в неделю);
# - В основном остаются те клиенты кто посещает занятия 2 раза в неделю;
# - Модель логистической регрессии показала себя лучше;
# - Самые надежные кластеры - `номер 2` (3% оттока) и `номер 0` (7% оттока).

# %% [markdown]
# ### Рекомендации для стратегии взаимодействия с клиентами и их удержания

# %% [markdown]
# На основании анализа можно предложить следующие рекомендации:
# - Проводить активную рекламную компанию в районе расположения фитнес-клуба для привлечения клиентов среди проживающих рядом граждан;
# - Система мотивации, направленная на покупку клиентом абонементов на 6 и 12 месяцев (скидки, розыгрыши и т.п.);
# - Привлечение граждан старше 30 лет;
# - Продолжать развивать программу "Приведи друга";
# - Стимулирование клиентов со стороны тренерского состава на более частое посещение тренировок (2 и более раз в неделю);
# - Расширить перечень иных услуг фитнес-центра (к примеру, организовать на территории центра сауну).
